# %% [markdown]
# Importando Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
sns.set()

# %% [markdown]
# Carregando dados

# %%
data = pd.read_csv("../data/country_clusters.csv")

# %%
data
# Out:
#      Country  Latitude  Longitude Language
# 0        USA     44.97    -103.77  English
# 1     Canada     62.40     -96.80  English
# 2     France     46.75       2.40   French
# 3         UK     54.01      -2.53  English
# 4    Germany     51.15      10.40   German
# 5  Australia    -25.45     133.11  English

# %% [markdown]
# Visualizando

# %%
plt.scatter(data["Longitude"], data["Latitude"])
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# Selecionando as Features

# %%
#primeiro argumento a quantidade de linhas, segundo as colunas 
X = data.iloc[:, 1:3] 
X
# Out:
#    Latitude  Longitude
# 0     44.97    -103.77
# 1     62.40     -96.80
# 2     46.75       2.40
# 3     54.01      -2.53
# 4     51.15      10.40
# 5    -25.45     133.11

# %% [markdown]
# Agrupando

# %%
kmeans = KMeans(3)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3)

# %% [markdown]
# *Agrupandos os resultados*
#
# Cria um array indiciando os clusters criados <br>
# 0, 1 e 2<br>
# 2 Países pertencem ao primeiro cluster (0)<br>
# 1 País pertence ao segundo cluster (1)<br>
# 3 Países pertencem ao segundo cluster (2)<br>

# %%
identified_clusters = kmeans.fit_predict(X)
identified_clusters
# Out:
# array([0, 0, 2, 2, 2, 1], dtype=int32)

# %% [markdown]
# Criando uma nova tabela
#
# Inserindo a coluna identificando os clusters

# %%
data_with_clusters = data.copy()
data_with_clusters["Clusters"] = identified_clusters
data_with_clusters
# Out:
#      Country  Latitude  Longitude Language  Clusters
# 0        USA     44.97    -103.77  English         0
# 1     Canada     62.40     -96.80  English         0
# 2     France     46.75       2.40   French         2
# 3         UK     54.01      -2.53  English         2
# 4    Germany     51.15      10.40   German         2
# 5  Australia    -25.45     133.11  English         1

# %%
plt.scatter(x=data_with_clusters["Longitude"], y=data_with_clusters["Latitude"], c=data_with_clusters["Clusters"], cmap="rainbow")
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()
